# %% [markdown]
# #Semana 1 secion 1

# %% [markdown]
# # Documentacion para  la practica de GIT semana 1 secion 1
#
# ## estudiante: Alvaro Baruch Cuevas Castro
# ## Gabriel Garcia Alvarez

# %% [markdown]
# ###  *Celda 2 – Configuración Inicial de Git*
#
# markdown
# ##  Configuración Inicial de Git
# Se configuraron las credenciales globales de Git:
#
#
# bash
# git config --global user.name "Alvaro"
# git config --global user.email "castrobaruch5@gmail.com"
# git config --list
#
# markdown
# **Salida:**
# user.name=Alvaro
# user.email=castrobaruch5@gmail.com
#
#
# ---

# %% [markdown]
# ### 🟦 *Celda 3 – Creación del Repositorio Principal*
#
# markdown
# ## 🚀 Paso 1: Creación del Repositorio Principal
#
#
# bash
# mkdir mi_proyecto
# cd mi_proyecto
# git init
#
#
# markdown
# **Salida:**
#
#
#
# Initialized empty Git repository in /mnt/c/Users/acuev/mi_proyecto/.git/
#
#
# ---

# %% [markdown]
# ### 🟩 *Celda 4 – Primer Commit*
#
# markdown
# ## 📝 Paso 2: Primer Commit - Archivo README
#
#
# bash
# git status
# echo "RepositorioGabAlva" > README.md
# git add README.md
# git commit -m "Primer commit: agregue README"
#
#
# markdown
# **Resultado del commit:**
#
#
#
# [master (root-commit) 307a5a5] Primer commit: agregue README
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
#
#
# ---

# %% [markdown]
# ### 🟦 *Celda 5 – Segundo Commit*
#
# markdown
# ## 🔄 Paso 3: Segundo Commit - Modificación del README
#
#
# bash
# echo "Nueva Linea" >> README.md
# git status
# git diff
# git add README.md
# git commit -m "Agregue nueva linea en README"
#
#
# markdown
# **Diferencias mostradas por `git diff`:**
#
#
# diff
# diff --git a/README.md b/README.md
# index 384file..fbblef8 100644
# --- a/README.md
# +++ b/README.md
# @@ -1 +1,2 @@
#  RepositorioGabAlva
# +Nueva linea
#
#
# markdown
# **Resultado del commit:**
# [master ad2bbea] Agregue nueva linea en README
#  1 file changed, 1 insertion(+)
#
#
# ---

# %% [markdown]
# ### 🟩 *Celda 6 – Creación de Subproyecto*
#
# markdown
# ## 📂 Paso 4: Creación de Subproyecto y Tercer Commit
#
#
# bash
# mkdir section1_git
# cd section1_git
# git init
#
#
# ---

# %% [markdown]
# ### 🟦 *Celda 7 – Archivo de Notas*
#
# markdown
# ## 📄 Paso 5: Creación del Archivo de Notas
#
#
# bash
# echo "Esta es mi primera línea de notas" > notas.txt
# echo "Aquí esta la segunda línea de notas" >> notas.txt
# echo "Y esta es la tercera y la ultima línea de los ejercicios practicos de github" >> notas.txt
# git add notas.txt
# git commit -m "Complete el ejercicio practico"
#
#
# markdown
# **Resultado del commit:**
#
#
#
# [master (root-commit) 5d285e6] Complete el ejercicio practico
#  1 file changed, 3 insertions(+)
#  create mode 100644 notas.txt
#
#
# ---

# %% [markdown]
# ### 🟩 *Celda 8 – Cuarto Commit*
#
# markdown
# ## ✅ Paso 6: Cuarto Commit - Modificación Final
#
#
# bash
# echo "Cuarta línea agregada en tercer commit" >> notas.txt
# git add notas.txt
# git commit -m "Agregue una nueva línea y hago el ultimo commit"
#
#
# markdown
# **Resultado del commit:**
#
#
#
# [master cca5c74] Agregue una nueva línea y hago el ultimo commit
#  1 file changed, 1 insertion(+)
#
#
# ---

# %% [markdown]
# ### 🟦 *Celda 9 – Verificación Final*
#
# markdown
# ## 📊 Verificación Final
#
#
# bash
# git log --oneline
#
#
# markdown
# **Historial de commits:**
#
#
#
# cca5c74 (HEAD -> master) Agregue una nueva línea y hago el ultimo commit
# 5d285e6 Complete el ejercicio practico
#
#
# ---

# %% [markdown]
# ### Pruebas Con Capturas
# ![Capt0.png](attachment:Capt0.png)
#
# ![Capt1.jpg](attachment:Capt1.jpg)
#
# ![Capt2.jpg](attachment:Capt2.jpg)
#
# ![Capt3.jpg](attachment:Capt3.jpg)
#
# ![Capt4.jpg](attachment:Capt4.jpg)
